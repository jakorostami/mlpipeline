# %%
import requests
import json
import pandas as pd

# %%
input_data = {
    "Date": ["14/11/2013", "20/12/2013", "01/01/2014"],
    "Product": ["Shirt", "Hair Band", "Shirt"],
    "Gender": ["Male", "Female", "Female"],
    "Device_Type": ["Mobile", "Web", "Mobile"],
    "State": ["New York", "Washington", "New York"],
    "City": ["New York City", "Seattle", "New York City"],
    "Category": ["Clothing", "Accessories", "Clothing"],
    "Customer_Login_type": ["Member", "Guest", "Member"],
    "Delivery_Type": ["Normal Delivery", "one-day deliver", "one-day deliver"],
    "Individual_Price_US$": [10.0, 27, 10],
    "Time": ["22:44:41", "00:41:24", "15:20:33"],
    "Quantity": [500, 50, 100]
    }

# %%
api_url = "http://localhost:8000/predict"

# %%
response = requests.post(api_url, json.dumps(input_data))

# %%
response.json()
# Out:
# {'transaction_result': [0.0, 0.0, 1.0],
#  'probability': [0.3602920788778071, 0.0, 0.6691203596288426],
#  'model_predictions': [{'AdaBoost': 0.5089938591029733,
#    'CatBoost': 0.951307080238991,
#    'Decision Tree': 1.0,
#    'Logistic Regression': 0.000941808417553207,
#    'MLPClassifier': 0.8483167384266872,
#    'Random Forest': 0.8935,
#    'XGBoost RandomForest': 0.8860503435134888,
#    'XGBoost': 0.9271091818809509},
#   {'AdaBoost': 0.5038069981353454,
#    'CatBoost': 0.6808589751743582,
#    'Decision Tree': 0.0,
#    'Logistic Regression': 0.7808276436142776,
#    'MLPClassifier': 0.8657779098392776,
#    'Random Forest': 0.8420059523809524,
#    'XGBoost RandomForest': 0.6091865301132202,
#    'XGBoost': 0.9063424468040466},
#   {'AdaBoost': 0.5099973385673273,
#    'CatBoost': 0.8560297187798132,
#    'Decision Tree': 0.3333333333333333,
#    'Logistic Regression': 0.6001371512542888,
#    'MLPClassifier': 0.8657139167642073,
#    'Random Forest': 0.7960026640026641,
#    'XGBoost RandomForest': 0.8768253922462463,
#    'XGBoost': 0.7614579200744629}],
#  'drift_detected': False,
#  'drift_details': {'Individual_Price_US$': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'Quantity': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'day_of_week': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'day_of_month': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'day_of_year': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'month': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'quarter': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'year': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'day_of_year_sin': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'day_of_year_cos': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'day_of_month_sin': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'day_of_month_cos': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'day_of_week_sin': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'day_of_week_cos': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'month_sin': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'month_cos': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'Product_code': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'Gender_code': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'Device_Type_code': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'State_code': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'City_code': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'Category_code': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'Customer_Login_type_code': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'Delivery_Type_code': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'weekday_name_code': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0},
#   'month_name_code': {'drift_detected': False,
#    'mean_difference': 0.0,
#    'std_difference': 0.0}}}

# %%
pd.json_normalize(response.json()).T
# Out:
#                                                                                                    0
# transaction_result                                                                   [0.0, 0.0, 1.0]
# probability                                            [0.3602920788778071, 0.0, 0.6691203596288426]
# model_predictions                                  [{'AdaBoost': 0.5089938591029733, 'CatBoost': ...
# drift_detected                                                                                 False
# drift_details.Individual_Price_US$.drift_detected                                              False
# ...                                                                                              ...
# drift_details.weekday_name_code.mean_difference                                                  0.0
# drift_details.weekday_name_code.std_difference                                                   0.0
# drift_details.month_name_code.drift_detected                                                   False
# drift_details.month_name_code.mean_difference                                                    0.0
# drift_details.month_name_code.std_difference                                                     0.0
#
# [82 rows x 1 columns]
